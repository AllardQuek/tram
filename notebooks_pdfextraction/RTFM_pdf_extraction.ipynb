# %% [markdown]
# ## Tabula
#
# Installation
# https://pypi.org/project/tabula-py/
#
# pip install tabula-py
#
# tabula-py docs
# https://www.pydoc.io/pypi/tabula-py-0.9.0/autoapi/wrapper/index.html
#
# **Read the Documentation! Useful parameters like multiple_tables, lattice, pandas_options are available**

# %% [markdown]
# ### Emotet

# %%
from tabula import read_pdf

def extract_tables(pdf_filepath):
    # Specify dict as pandas option so that first row will not be treated as labels
    df = read_pdf(pdf_filepath, pages='all', multiple_tables=False, stream=True)
    return df[0]

# %%
df = extract_tables('Mirai1.pdf')

# %%
# Group by IDs?
df.sample(30)
# Out:
#         ID                Name  \
# 212    NaN                 NaN
# 169    NaN                 NaN
# 142    NaN                 NaN
# 229    NaN                 NaN
# 164    NaN                 NaN
# 263    NaN                 NaN
# 96     NaN                 NaN
# 21     NaN                 NaN
# 344    NaN            Scanning
# 248    NaN                 NaN
# 73     NaN                 NaN
# 202    NaN                 NaN
# 209    NaN                 NaN
# 80     NaN                 NaN
# 118    NaN                 NaN
# 343  T1046     Network Service
# 159    NaN                 NaN
# 97     NaN                 NaN
# 33     NaN                 NaN
# 87     NaN                 NaN
# 356    NaN                 NaN
# 222    NaN                 NaN
# 116    NaN                 NaN
# 11     NaN                 NaN
# 179    NaN                 NaN
# 330    NaN                 NaN
# 220    NaN                 NaN
# 126    NaN                 NaN
# 160    NaN                 NaN
# 213  T1043  Commonly Used Port
#
#                                    Identified Sentence
# 212                                                  !
# 169                                                NaN
# 142                                                NaN
# 229                                                NaN
# 164                              Existing Mirai Botnet
# 263                                 saw a while ago on
# 96   On the other hand, from the perspective of the...
# 21                                            after on
# 344                                 11% scan both port
# 248  The New Variant Shares Some of the Infrastruct...
# 73                                  please re-download
# 202                                      7547 and 5555
# 209                    timeserver.host) and two report
# 80      The new mirai has two C2s (securityupdates.us,
# 118                                              data.
# 343  Among them, 79% only scan port 23 and 6.4% onl...
# 159  the data from 2016-11-26 and later to obtain u...
# 97                                network, the scan on
# 33                                                 NaN
# 87                                                 NaN
# 356                                                NaN
# 222                        maintained at a high level.
# 116  the data from 2016-11-26 and later to obtain u...
# 11                    2016-11-27 17:04:02(all GMT +8).
# 179                                       and smoothly
# 330                                       the previous
# 220  The figure shows that, bot's growth rate quick...
# 126                                                NaN
# 160                                      7547 and 5555
# 213  The total number of bots on current port 7547 ...

# %%
df.head(20)
# Out:
#        ID                Name  \
# 0   T1046     Network Service
# 1     NaN            Scanning
# 2     NaN                 NaN
# 3   T1065     Uncommonly Used
# 4     NaN                Port
# 5     NaN                 NaN
# 6     NaN                 NaN
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14  T1043  Commonly Used Port
# 15    NaN                 NaN
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18    NaN                 NaN
# 19    NaN                 NaN
#
#                                   Identified Sentence
# 0   Much of the new mirai variant that scans port ...
# 1                                  covered by various
# 2                                            sources.
# 3   The following table lists first seen time of “...
# 4                                          “new” ones
# 5                              that hit our honeypot.
# 6                                                 NaN
# 7   You can see the variant on port 7547 first sho...
# 8                                2016-11-26 21:27:23,
# 9   and first observed for the variant on port 555...
# 10                                           after on
# 11                   2016-11-27 17:04:02(all GMT +8).
# 12                                                NaN
# 13                                                  !
# 14  The following table lists first seen time of “...
# 15                                         “new” ones
# 16                             that hit our honeypot.
# 17                                                NaN
# 18  You can see the variant on port 7547 first sho...
# 19                               2016-11-26 21:27:23,

# %%
tids = list(df['ID'])

# %%
type(tids)
# Out:
# list

# %%
def extract_tids(df):
    tids = list(df['ID'])    # Convert series to list to allow easier indexing
    
    indexes = []
    valid_tids = []
    for id in tids:
        # Checking i == np.nan doesn't work
        if isinstance(id, str):
            index = tids.index(id)
            indexes.append(index)
            valid_tids.append(id)
    
    # Remember to add first and last indexes (0 and 29)
    # So first batch from 0 to 7 exclusive and last batch will be from 13 to 29 exclusive
    if indexes[0] != 0:
        indexes.insert(0, 0)
    indexes.append(len(tids))    
    return valid_tids, indexes

# %%
valid_tids, indexes = extract_tids(df)
valid_tids, indexes
# Out:
# (['T1046',
#   'T1065',
#   'T1043',
#   'T1065',
#   'T1046',
#   'T1043',
#   'T1048',
#   'T1065',
#   'T1046',
#   'T1008',
#   'T1043',
#   'T1008',
#   'T1065',
#   'T1046',
#   'T1008',
#   'T1043',
#   'T1065',
#   'T1046',
#   'T1043',
#   'T1046',
#   'T1046'],
#  [0,
#   3,
#   14,
#   3,
#   0,
#   14,
#   43,
#   3,
#   0,
#   171,
#   14,
#   171,
#   3,
#   0,
#   171,
#   14,
#   3,
#   0,
#   14,
#   0,
#   0,
#   364])

# %%
def extract_names(df):
    names = list(df['Name'])
    valid_names = []
    condition = False
    for i in range(len(names)):
        if condition:
            i+=1
        if i == len(names):
            break
        # Checking i == np.nan doesn't work
        if isinstance(names[i], str):
            n = names[i]
            if isinstance(names[i+1], str):
                n = names[i] + ' ' + names[i+1]
                condition = True
            valid_names.append(n)
    return valid_names

# %%
valid_names = extract_names(df)
valid_names
# Out:
# ['Network Service Scanning',
#  'Uncommonly Used Port',
#  'Port',
#  'Commonly Used Port',
#  'Uncommonly Used Port',
#  'Port',
#  'Network Service Scanning',
#  'Scanning',
#  'Commonly Used Port',
#  'Exfiltration Over Alternative Protocol',
#  'Alternative Protocol',
#  'Uncommonly Used Port',
#  'Port',
#  'Network Service Scanning',
#  'Scanning',
#  'Fallback Channels',
#  'Commonly Used Port',
#  'Fallback Channels',
#  'Uncommonly Used Port',
#  'Port',
#  'Network Service Scanning',
#  'Scanning',
#  'Fallback Channels',
#  'Commonly Used Port',
#  'Uncommonly Used Port',
#  'Port',
#  'Network Service Scanning',
#  'Scanning',
#  'Commonly Used Port',
#  'Network Service Scanning',
#  'Scanning Network Service',
#  'Network Service Scanning',
#  'Scanning']

# %%
sentences = df['Identified Sentence']
sentences.values
# Out:
# array(['Much of the new mirai variant that scans port 7547 has been',
#        'covered by various', 'sources.',
#        'The following table lists first seen time of “old” mirai and the',
#        '“new” ones', 'that hit our honeypot.', nan,
#        'You can see the variant on port 7547 first shown up on',
#        '2016-11-26 21:27:23,',
#        'and first observed for the variant on port 5555 was one day',
#        'after on', '2016-11-27 17:04:02(all GMT +8).', nan, '!',
#        'The following table lists first seen time of “old” mirai and the',
#        '“new” ones', 'that hit our honeypot.', nan,
#        'You can see the variant on port 7547 first shown up on',
#        '2016-11-26 21:27:23,',
#        'and first observed for the variant on port 5555 was one day',
#        'after on', '2016-11-27 17:04:02(all GMT +8).', nan, '!',
#        '[](/content/images/2016/11/03-bot-current-growth-rate-on-all-',
#        'port.jpg)', nan,
#        'Currently, the growth rate of the bot on port 7547 has far',
#        'exceeded the number', 'of bots on port 23/2323.',
#        '[](/content/images/2016/11/03-bot-current-growth-rate-on-all-',
#        'port.jpg)', nan,
#        'Currently, the growth rate of the bot on port 7547 has far',
#        'exceeded the number', 'of bots on port 23/2323.',
#        '[](/content/images/2016/11/03-bot-current-growth-rate-on-all-',
#        'port.jpg)', nan,
#        'Currently, the growth rate of the bot on port 7547 has far',
#        'exceeded the number', 'of bots on port 23/2323.',
#        'The total number of bots on current port 7547 has already',
#        'exceeded 30,000.', nan,
#        'Bot growth rate on port 7547, per 10 minutes:', nan, nan, nan,
#        "The figure shows that, bot's growth rate quickly reached a peak,",
#        'and smoothly', 'maintained at a high level.', nan,
#        'On the other hand, from the perspective of the backbone',
#        'network, the scan on',
#        'port 7547 began to rise sharply in the evening of 2016-11-26.',
#        nan, nan, nan,
#        'In terms of the geographical distribution of the newly infected',
#        'bot, Brazil is',
#        'still far ahead of the others, which is consistent with the',
#        'geographical', 'distribution of the existing mirai botnet.', nan,
#        nan, nan,
#        'We provide various statistics and data downloads of Mirai-',
#        'infected devices at',
#        'http://data.netlab.360.com/mirai-scanner for researchers.', nan,
#        'For those who have been using API to access our bot list,',
#        'please re-download',
#        'the data from 2016-11-26 and later to obtain updates for port',
#        '7547 and 5555', 'data.', nan,
#        'The New Variant Shares Some of the Infrastructure of the',
#        'Existing Mirai Botnet',
#        'The new mirai has two C2s (securityupdates.us,',
#        'timeserver.host) and two report',
#        'servers (rep.securityupdates.us, ntp.timeserver.host)', nan, '!',
#        'The total number of bots on current port 7547 has already',
#        'exceeded 30,000.', nan,
#        'Bot growth rate on port 7547, per 10 minutes:', nan, nan, nan,
#        "The figure shows that, bot's growth rate quickly reached a peak,",
#        'and smoothly', 'maintained at a high level.', nan,
#        'On the other hand, from the perspective of the backbone',
#        'network, the scan on',
#        'port 7547 began to rise sharply in the evening of 2016-11-26.',
#        nan, nan, nan,
#        'In terms of the geographical distribution of the newly infected',
#        'bot, Brazil is',
#        'still far ahead of the others, which is consistent with the',
#        'geographical', 'distribution of the existing mirai botnet.', nan,
#        nan, nan,
#        'We provide various statistics and data downloads of Mirai-',
#        'infected devices at',
#        'http://data.netlab.360.com/mirai-scanner for researchers.', nan,
#        'For those who have been using API to access our bot list,',
#        'please re-download',
#        'the data from 2016-11-26 and later to obtain updates for port',
#        '7547 and 5555', 'data.', nan,
#        'The New Variant Shares Some of the Infrastructure of the',
#        'Existing Mirai Botnet', nan,
#        'The new mirai has two C2s (securityupdates.us,',
#        'timeserver.host) and two report',
#        'servers (rep.securityupdates.us, ntp.timeserver.host)', nan, '!',
#        'The total number of bots on current port 7547 has already',
#        'exceeded 30,000.', nan,
#        'Bot growth rate on port 7547, per 10 minutes:', nan, nan, nan,
#        "The figure shows that, bot's growth rate quickly reached a peak,",
#        'and smoothly', 'maintained at a high level.', nan,
#        'On the other hand, from the perspective of the backbone',
#        'network, the scan on',
#        'port 7547 began to rise sharply in the evening of 2016-11-26.',
#        nan, nan, nan,
#        'In terms of the geographical distribution of the newly infected',
#        'bot, Brazil is',
#        'still far ahead of the others, which is consistent with the',
#        'geographical', 'distribution of the existing mirai botnet.', nan,
#        nan, nan,
#        'We provide various statistics and data downloads of Mirai-',
#        'infected devices at',
#        'http://data.netlab.360.com/mirai-scanner for researchers.', nan,
#        'For those who have been using API to access our bot list,',
#        'please re-download',
#        'the data from 2016-11-26 and later to obtain updates for port',
#        '7547 and 5555', 'data.', nan,
#        'The New Variant Shares Some of the Infrastructure of the',
#        'Existing Mirai Botnet', nan,
#        'The new mirai has two C2s (securityupdates.us,',
#        'timeserver.host) and two report',
#        'servers (rep.securityupdates.us, ntp.timeserver.host)', nan, '!',
#        'The total number of bots on current port 7547 has already',
#        'exceeded 30,000.', nan,
#        'Bot growth rate on port 7547, per 10 minutes:', nan, nan, nan,
#        "The figure shows that, bot's growth rate quickly reached a peak,",
#        'and smoothly', 'maintained at a high level.',
#        'On the other hand, from the perspective of the backbone',
#        'network, the scan on',
#        'port 7547 began to rise sharply in the evening of 2016-11-26.',
#        nan, nan, nan,
#        'In terms of the geographical distribution of the newly infected',
#        'bot, Brazil is',
#        'still far ahead of the others, which is consistent with the',
#        'geographical', 'distribution of the existing mirai botnet.', nan,
#        nan, nan,
#        'We provide various statistics and data downloads of Mirai-',
#        'infected devices at',
#        'http://data.netlab.360.com/mirai-scanner for researchers.', nan,
#        'For those who have been using API to access our bot list,',
#        'please re-download',
#        'the data from 2016-11-26 and later to obtain updates for port',
#        '7547 and 5555', 'data.', nan,
#        'The New Variant Shares Some of the Infrastructure of the',
#        'Existing Mirai Botnet', nan,
#        'The new mirai has two C2s (securityupdates.us,',
#        'timeserver.host) and two report',
#        'servers (rep.securityupdates.us, ntp.timeserver.host)', nan, '!',
#        'The total number of bots on current port 7547 has already',
#        'exceeded 30,000.', nan,
#        'Bot growth rate on port 7547, per 10 minutes:', nan, nan, nan,
#        "The figure shows that, bot's growth rate quickly reached a peak,",
#        'and smoothly', 'maintained at a high level.', nan,
#        'On the other hand, from the perspective of the backbone',
#        'network, the scan on',
#        'port 7547 began to rise sharply in the evening of 2016-11-26.',
#        nan, nan, nan,
#        'In terms of the geographical distribution of the newly infected',
#        'bot, Brazil is',
#        'still far ahead of the others, which is consistent with the',
#        'geographical', 'distribution of the existing mirai botnet.', nan,
#        nan, nan,
#        'We provide various statistics and data downloads of Mirai-',
#        'infected devices at',
#        'http://data.netlab.360.com/mirai-scanner for researchers.', nan,
#        'For those who have been using API to access our bot list,',
#        'please re-download',
#        'the data from 2016-11-26 and later to obtain updates for port',
#        '7547 and 5555', 'data.', nan,
#        'The New Variant Shares Some of the Infrastructure of the',
#        'Existing Mirai Botnet', nan,
#        'The new mirai has two C2s (securityupdates.us,',
#        'timeserver.host) and two report',
#        'servers (rep.securityupdates.us, ntp.timeserver.host)', nan, '!',
#        '[](/content/images/2016/11/07-two-c2-server-and-two-report-',
#        'server-in-one-', 'marai-sample---the-port-7547-varaint.jpg)', nan,
#        'It is noteworthy the exact combination, both C2s and report',
#        'servers had',
#        'previously been embedded in the “old” mirai sample that we',
#        'saw a while ago on', '2016-11-09.', nan,
#        'Detail of the sample of 2016-11-09 variant:', nan,
#        'CRC32: 2BD6603A MD5:', 'EF713BDD7B06097447A25F4B35C738F6 SHA-1:',
#        '44D9C6A682E48DFA86BACDBD68F11A1F3CB78D07', nan, '!',
#        '[](/content/images/2016/11/07-two-c2-server-and-two-report-',
#        'server-in-one-', 'marai-sample.jpg)', nan, 'Bot Overlap', nan,
#        'In other words, the operator of new variant on port 7547 and',
#        'the previous',
#        'mirai operator are very likely the same group of people.',
#        'The following diagram shows the overlap of all the bots we',
#        'captured in our',
#        'honeypot that have scanned port 23/2323/5555/7547.', nan,
#        'We can see that:', nan,
#        '96.4% of the Mirai Bots scan port 23 or port 2323.',
#        '[](/content/images/2016/11/07-two-c2-server-and-two-report-',
#        'server-in-one-', 'marai-sample.jpg)', nan, 'Bot Overlap', nan,
#        'In other words, the operator of new variant on port 7547 and',
#        'the previous',
#        'mirai operator are very likely the same group of people.', nan,
#        'The following diagram shows the overlap of all the bots we',
#        'captured in our',
#        'honeypot that have scanned port 23/2323/5555/7547.', nan,
#        'We can see that:', nan,
#        '96.4% of the Mirai Bots scan port 23 or port 2323.',
#        '[](/content/images/2016/11/07-two-c2-server-and-two-report-',
#        'server-in-one-', 'marai-sample.jpg)', nan, 'Bot Overlap', nan,
#        'In other words, the operator of new variant on port 7547 and',
#        'the previous',
#        'mirai operator are very likely the same group of people.', nan,
#        'The following diagram shows the overlap of all the bots we',
#        'captured in our',
#        'honeypot that have scanned port 23/2323/5555/7547.', nan,
#        'We can see that:', nan,
#        '96.4% of the Mirai Bots scan port 23 or port 2323.',
#        '[](/content/images/2016/11/07-two-c2-server-and-two-report-',
#        'server-in-one-', 'marai-sample.jpg)', nan, 'Bot Overlap', nan,
#        'In other words, the operator of new variant on port 7547 and',
#        'the previous',
#        'mirai operator are very likely the same group of people.', nan,
#        'The following diagram shows the overlap of all the bots we',
#        'captured in our',
#        'honeypot that have scanned port 23/2323/5555/7547.', nan,
#        'We can see that:', nan,
#        '96.4% of the Mirai Bots scan port 23 or port 2323.',
#        'Among them, 79% only scan port 23 and 6.4% only scan 2323,',
#        '11% scan both port', '23 and 2323.',
#        'Among them, 79% only scan port 23 and 6.4% only scan 2323,',
#        '11% scan both port', '23 and 2323.',
#        'Among them, 79% only scan port 23 and 6.4% only scan 2323,',
#        '11% scan both port', '23 and 2323.',
#        'About 3.1% of the Mirai bots only scan port 7547.', nan,
#        'No more than 0.1% of the bots show other cross-scanning',
#        'behaviors among the', 'four-ports, which is still quite rare.',
#        nan, 'Infected Device Breakdown', nan,
#        'All together we have logged 46,653 IPs that were infected with',
#        'this new 7547',
#        'variants, and we tried to ID these known infected IPs by sending',
#        'out requests',
#        'that emulate tr064|tr069 protocol so we would be able to get',
#        'accurate device', 'info.'], dtype=object)

# %%
def extract_sentences(df, indexes):
    sentences = df['Identified Sentence']
    
    all_sents = []

    for i in range(0, len(indexes)): 
        # If reached last available index, break to avoid IndexError
        if i == len(indexes) - 1:
            print("NO MORE BATCHES, BREAKING")
            break

        # Define start and end indexes
        start = indexes[i]
        end = indexes[i+1]        
        print(f"STARTING ON BATCH {i+1} in range ({start}, {end})")
        
        # Deal with each subsents 1 at a time
        subsents = sentences[start:end]
#         print(subsents, '\n\n')

        batch_sents = []
        full_sent = ''

        # Range: (0,7), (7,10), (10,13), (13,29)
        for i in range(start, end):
            if isinstance(subsents[i], str):
                full_sent += ' ' + subsents[i]

            if i+1==end or isinstance(subsents[i+1], float):
                batch_sents.append(full_sent)
                full_sent = ''
            else: 
                # Do nothing if current sentence is nan
                pass

        all_sents.append(batch_sents)
        
    return all_sents

all_sents = extract_sentences(df[0], indexes)

# %% [markdown]
# ### Implementation without lattice=True

# %% [markdown]
# ##### Splitting

# %% [markdown]
# ##### Handle Threat IDs

# %% [markdown]
# ##### Handle Names

# %% [markdown]
# ##### Handle Sentences

# %%
def extract_sentences(df, indexes):
    sentences = df['Identified Sentence']
    
    all_sents = []

    for i in range(0, len(indexes)): 
        # If reached last available index, break to avoid IndexError
        if i == len(indexes) - 1:
            print("NO MORE BATCHES, BREAKING")
            break

        # Define start and end indexes
        start = indexes[i]
        end = indexes[i+1]        
        print(f"STARTING ON BATCH {i+1} in range ({start}, {end})")
        
        # Deal with each subsents 1 at a time
        subsents = sentences[start:end]
#         print(subsents, '\n\n')

        batch_sents = []
        full_sent = ''

        # Range: (0,7), (7,10), (10,13), (13,29)
        for i in range(start, end):
            if isinstance(subsents[i], str):
                full_sent += ' ' + subsents[i]

            if i+1==end or isinstance(subsents[i+1], float):
                batch_sents.append(full_sent)
                full_sent = ''
            else: 
                # Do nothing if current sentence is nan
                pass

        all_sents.append(batch_sents)
        
    return all_sents

all_sents = extract_sentences(df[0], indexes)

# %%
count = 1
for batch in all_sents:
    print(f"BATCH {count}")
    for s in batch:
        print(s)
    print()
    count += 1
# Out:
# BATCH 1
#  Later versions of the software saw the addition of spamming and malware delivery services—including other banking Trojans.
#  Emotet uses functionality that helps the software evade detection by some anti-malware products.
#
# BATCH 2
#  The infection may arrive either via malicious script, macro- enabled document files, or malicious link.
#
# BATCH 3
#  The infection may arrive either via malicious script, macro- enabled document files, or malicious link.
#
# BATCH 4
#  This allows the attackers to install updated versions of the software, install additional malware such as other banking Trojans, or to act as a dumping ground for stolen information such as financial credentials, usernames and passwords, and email addresses.
#  Latest Emotet news
#  Emotet is back: botnet springs back to life with new spam campaign
#  Emotet on the rise with heavy spam campaign
#  Malware analysis: decoding Emotet, part 2

# %%
print(valid_tids, '\n')
print(valid_names, '\n')
print(all_sents)
# Out:
# ['T1063', 'T1064', 'T1204', 'T1003']
#
# ['Security Software Discovery', 'Scripting', 'User Execution', 'Credential Dumping']
#
# [[' Later versions of the software saw the addition of spamming and malware delivery services—including other banking Trojans.', ' Emotet uses functionality that helps the software evade detection by some anti-malware products.'], [' The infection may arrive either via malicious script, macro- enabled document files, or malicious link.'], [' The infection may arrive either via malicious script, macro- enabled document files, or malicious link.'], [' This allows the attackers to install updated versions of the software, install additional malware such as other banking Trojans, or to act as a dumping ground for stolen information such as financial credentials, usernames and passwords, and email addresses.', ' Latest Emotet news', ' Emotet is back: botnet springs back to life with new spam campaign', ' Emotet on the rise with heavy spam campaign', ' Malware analysis: decoding Emotet, part 2']]

# %% [markdown]
# for every batch, insert each sentence with name_i and id_i
#
# i = 0: all_sents[0], name[0], id[0]
# i += 1
#
# .
#
# .
#
# .

# %% [markdown]
# #### For last page's table

# %%
df[1]
# Out:
#        ID                Name  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6   T1192  Spearphishing Link
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14    NaN                 NaN
# 15    NaN                 NaN
# 16    NaN                 NaN
#
#                                   Identified Sentence
# 0           Malware analysis: decoding Emotet, part 1
# 1                                                 NaN
# 2                             How does Emotet spread?
# 3                                                 NaN
# 4   The primary distribution method for Emotet is ...
# 5                                            malspam.
# 6   Since these emails are coming from your hijack...
# 7                                 account, the emails
# 8   look less like spam and the recipients, feelin...
# 9                                         inclined to
# 10        click bad URLs and download infected files.
# 11                                                NaN
# 12  If a connected network is present, Emotet spre...
# 13                                     list of common
# 14  passwords, guessing its way onto other connect...
# 15                                   in a brute-force
# 16                                            attack.

# %%
valid_tids1, indexes1 = extract_tids(df[1])
valid_tids1, indexes1
# Out:
# (['T1192'], [0, 6, 17])

# %%
valid_names1 = extract_names(df[1])
valid_names1
# Out:
# ['Spearphishing Link']

# %%
all_sents1 = extract_sentences(df[1], indexes1)
# Out:
# STARTING ON BATCH 1 in range (0, 6)
# STARTING ON BATCH 2 in range (6, 17)
# NO MORE BATCHES, BREAKING

# %%
count = 1
for batch in all_sents1:
    print(f"BATCH {count}")
    for s in batch:
        print(s)
    print()
    count += 1
# Out:
# BATCH 1
#  Malware analysis: decoding Emotet, part 1
#  How does Emotet spread?
#  The primary distribution method for Emotet is through malspam.
#
# BATCH 2
#  Since these emails are coming from your hijacked email account, the emails look less like spam and the recipients, feeling safe, are more inclined to click bad URLs and download infected files.
#  If a connected network is present, Emotet spreads using a list of common passwords, guessing its way onto other connected systems in a brute-force attack.

# %%
print(valid_tids1, '\n')
print(valid_names1, '\n')
print(all_sents1)
# Out:
# ['T1192']
#
# ['Spearphishing Link']
#
# [[' Malware analysis: decoding Emotet, part 1', ' How does Emotet spread?', ' The primary distribution method for Emotet is through malspam.'], [' Since these emails are coming from your hijacked email account, the emails look less like spam and the recipients, feeling safe, are more inclined to click bad URLs and download infected files.', ' If a connected network is present, Emotet spreads using a list of common passwords, guessing its way onto other connected systems in a brute-force attack.']]

# %% [markdown]
# ### Final pipeline

# %%
df = extract_tables('Emotet.pdf')
for d in df:
    # Ensure each table has standardised column names
    d.columns = ['ID', 'Name', 'Identified Sentence']
    valid_tids, indexes = extract_tids(d)
    valid_names = extract_names(d)
    all_sents = extract_sentences(d, indexes)

    print('\nVALID T_IDS:', valid_tids)
    print('VALID NAMES:', valid_names)
    print('SENTENCES:')
    count = 1
    for batch in all_sents:
        print(f"Batch {count}")
        for s in batch:
            print(s)
        print()
        count += 1
    print('-------------------------------------------------------------------\n')
# Out:
# STARTING ON BATCH 1 in range (0, 7)
# STARTING ON BATCH 2 in range (7, 10)
# STARTING ON BATCH 3 in range (10, 13)
# STARTING ON BATCH 4 in range (13, 29)
# NO MORE BATCHES, BREAKING
#
# VALID T_IDS: ['T1063', 'T1064', 'T1204', 'T1003']
# VALID NAMES: ['Security Software Discovery', 'Scripting', 'User Execution', 'Credential Dumping']
# SENTENCES:
# Batch 1
#  Later versions of the software saw the addition of spamming and malware delivery services—including other banking Trojans.
#  Emotet uses functionality that helps the software evade detection by some anti-malware products.
#
# Batch 2
#  The infection may arrive either via malicious script, macro- enabled document files, or malicious link.
#
# Batch 3
#  The infection may arrive either via malicious script, macro- enabled document files, or malicious link.
#
# Batch 4
#  This allows the attackers to install updated versions of the software, install additional malware such as other banking Trojans, or to act as a dumping ground for stolen information such as financial credentials, usernames and passwords, and email addresses.
#  Latest Emotet news
#  Emotet is back: botnet springs back to life with new spam campaign
#  Emotet on the rise with heavy spam campaign
#  Malware analysis: decoding Emotet, part 2
#
# -------------------------------------------------------------------
#
# STARTING ON BATCH 1 in range (0, 6)
# STARTING ON BATCH 2 in range (6, 17)
# NO MORE BATCHES, BREAKING
#
# VALID T_IDS: ['T1192']
# VALID NAMES: ['Spearphishing Link']
# SENTENCES:
# Batch 1
#  Malware analysis: decoding Emotet, part 1
#  How does Emotet spread?
#  The primary distribution method for Emotet is through malspam.
#
# Batch 2
#  Since these emails are coming from your hijacked email account, the emails look less like spam and the recipients, feeling safe, are more inclined to click bad URLs and download infected files.
#  If a connected network is present, Emotet spreads using a list of common passwords, guessing its way onto other connected systems in a brute-force attack.
#
# -------------------------------------------------------------------

# %%
df = extract_tables('Mirai1.pdf')
for d in df:
    # Ensure each table has standardised column names
    d.columns = ['ID', 'Name', 'Identified Sentence']
    
    # If 1st row consists of labels
    if d['ID'].iloc[0] == 'ID':
        # Remove that row permanently with inplace=True
        d.drop([0], inplace=True)
        
    valid_tids, indexes = extract_tids(d)
    valid_names = extract_names(d)
    all_sents = extract_sentences(d, indexes)

    print('\nVALID T_IDS:', valid_tids)
    print('VALID NAMES:', valid_names)
    print('SENTENCES:')
    count = 1
    for batch in all_sents:
        print(f"Batch {count}")
        for s in batch:
            print(s)
        print()
        count += 1
    print('-------------------------------------------------------------------\n')
# Out:
# STARTING ON BATCH 1 in range (0, 3)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-c08d930380ca> in <module>
#      11     valid_tids, indexes = extract_tids(d)
#      12     valid_names = extract_names(d)
# ---> 13     all_sents = extract_sentences(d, indexes)
#      14
#      15     print('\nVALID T_IDS:', valid_tids)
#
# <ipython-input-21-5369f9f63125> in extract_sentences(df, indexes)
#      24         # Range: (0,7), (7,10), (10,13), (13,29)
#      25         for i in range(start, end):
# ---> 26             if isinstance(subsents[i], str):
#      27                 full_sent += ' ' + subsents[i]
#      28
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df = extract_tables('Mirai1.pdf')
for d in df:
     # Ensure each table has standardised column names
    d.columns = ['ID', 'Name', 'Identified Sentence']
    
    # If 1st row consists of labels
    if d['ID'].iloc[0] == 'ID':
        # Remove that row permanently with inplace=True
        d.drop([0], inplace=True)
        
    print(d)
# Out:
#        ID                Name  \
# 1   T1046     Network Service
# 2     NaN            Scanning
# 3     NaN                 NaN
# 4   T1065     Uncommonly Used
# 5     NaN                Port
# 6     NaN                 NaN
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14    NaN                 NaN
# 15  T1043  Commonly Used Port
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18    NaN                 NaN
# 19    NaN                 NaN
# 20    NaN                 NaN
# 21    NaN                 NaN
# 22    NaN                 NaN
# 23    NaN                 NaN
# 24    NaN                 NaN
# 25    NaN                 NaN
# 26  T1065     Uncommonly Used
# 27    NaN                Port
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
#
#                                   Identified Sentence
# 1   Much of the new mirai variant that scans port ...
# 2                                  covered by various
# 3                                            sources.
# 4   The following table lists first seen time of “...
# 5                                          “new” ones
# 6                              that hit our honeypot.
# 7                                                 NaN
# 8   You can see the variant on port 7547 first sho...
# 9                                2016-11-26 21:27:23,
# 10  and first observed for the variant on port 555...
# 11                                           after on
# 12                   2016-11-27 17:04:02(all GMT +8).
# 13                                                NaN
# 14                                                  !
# 15  The following table lists first seen time of “...
# 16                                         “new” ones
# 17                             that hit our honeypot.
# 18                                                NaN
# 19  You can see the variant on port 7547 first sho...
# 20                               2016-11-26 21:27:23,
# 21  and first observed for the variant on port 555...
# 22                                           after on
# 23                   2016-11-27 17:04:02(all GMT +8).
# 24                                                NaN
# 25                                                  !
# 26  [](/content/images/2016/11/03-bot-current-grow...
# 27                                          port.jpg)
# 28                                                NaN
# 29  Currently, the growth rate of the bot on port ...
# 30                                exceeded the number
# 31                           of bots on port 23/2323.
#        ID                  Name  \
# 0   T1046       Network Service
# 1     NaN              Scanning
# 2     NaN                   NaN
# 3     NaN                   NaN
# 4     NaN                   NaN
# 5     NaN                   NaN
# 6   T1043    Commonly Used Port
# 7     NaN                   NaN
# 8     NaN                   NaN
# 9     NaN                   NaN
# 10    NaN                   NaN
# 11    NaN                   NaN
# 12  T1048     Exfiltration Over
# 13    NaN  Alternative Protocol
# 14    NaN                   NaN
# 15    NaN                   NaN
# 16    NaN                   NaN
# 17    NaN                   NaN
# 18    NaN                   NaN
# 19    NaN                   NaN
# 20    NaN                   NaN
# 21    NaN                   NaN
# 22    NaN                   NaN
# 23    NaN                   NaN
# 24    NaN                   NaN
# 25    NaN                   NaN
# 26    NaN                   NaN
# 27    NaN                   NaN
# 28    NaN                   NaN
# 29    NaN                   NaN
# 30    NaN                   NaN
# 31    NaN                   NaN
# 32    NaN                   NaN
# 33    NaN                   NaN
# 34    NaN                   NaN
# 35    NaN                   NaN
# 36    NaN                   NaN
# 37    NaN                   NaN
# 38    NaN                   NaN
# 39    NaN                   NaN
# 40    NaN                   NaN
# 41    NaN                   NaN
# 42    NaN                   NaN
# 43    NaN                   NaN
# 44    NaN                   NaN
# 45    NaN                   NaN
# 46    NaN                   NaN
# 47    NaN                   NaN
# 48    NaN                   NaN
#
#                                   Identified Sentence
# 0   [](/content/images/2016/11/03-bot-current-grow...
# 1                                           port.jpg)
# 2                                                 NaN
# 3   Currently, the growth rate of the bot on port ...
# 4                                 exceeded the number
# 5                            of bots on port 23/2323.
# 6   [](/content/images/2016/11/03-bot-current-grow...
# 7                                           port.jpg)
# 8                                                 NaN
# 9   Currently, the growth rate of the bot on port ...
# 10                                exceeded the number
# 11                           of bots on port 23/2323.
# 12  The total number of bots on current port 7547 ...
# 13                                   exceeded 30,000.
# 14                                                NaN
# 15      Bot growth rate on port 7547, per 10 minutes:
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  The figure shows that, bot's growth rate quick...
# 20                                       and smoothly
# 21                        maintained at a high level.
# 22                                                NaN
# 23  On the other hand, from the perspective of the...
# 24                               network, the scan on
# 25  port 7547 began to rise sharply in the evening...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  In terms of the geographical distribution of t...
# 30                                     bot, Brazil is
# 31  still far ahead of the others, which is consis...
# 32                                       geographical
# 33         distribution of the existing mirai botnet.
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  We provide various statistics and data downloa...
# 38                                infected devices at
# 39  http://data.netlab.360.com/mirai-scanner for r...
# 40                                                NaN
# 41  For those who have been using API to access ou...
# 42                                 please re-download
# 43  the data from 2016-11-26 and later to obtain u...
# 44                                      7547 and 5555
# 45                                              data.
# 46                                                NaN
# 47  The New Variant Shares Some of the Infrastruct...
# 48                              Existing Mirai Botnet
#        ID             Name                                Identified Sentence
# 0     NaN              NaN     The new mirai has two C2s (securityupdates.us,
# 1     NaN              NaN                    timeserver.host) and two report
# 2     NaN              NaN  servers (rep.securityupdates.us, ntp.timeserve...
# 3     NaN              NaN                                                NaN
# 4     NaN              NaN                                                  !
# 5   T1065  Uncommonly Used  The total number of bots on current port 7547 ...
# 6     NaN             Port                                   exceeded 30,000.
# 7     NaN              NaN                                                NaN
# 8     NaN              NaN      Bot growth rate on port 7547, per 10 minutes:
# 9     NaN              NaN                                                NaN
# 10    NaN              NaN                                                NaN
# 11    NaN              NaN                                                NaN
# 12    NaN              NaN  The figure shows that, bot's growth rate quick...
# 13    NaN              NaN                                       and smoothly
# 14    NaN              NaN                        maintained at a high level.
# 15    NaN              NaN                                                NaN
# 16    NaN              NaN  On the other hand, from the perspective of the...
# 17    NaN              NaN                               network, the scan on
# 18    NaN              NaN  port 7547 began to rise sharply in the evening...
# 19    NaN              NaN                                                NaN
# 20    NaN              NaN                                                NaN
# 21    NaN              NaN                                                NaN
# 22    NaN              NaN  In terms of the geographical distribution of t...
# 23    NaN              NaN                                     bot, Brazil is
# 24    NaN              NaN  still far ahead of the others, which is consis...
# 25    NaN              NaN                                       geographical
# 26    NaN              NaN         distribution of the existing mirai botnet.
# 27    NaN              NaN                                                NaN
# 28    NaN              NaN                                                NaN
# 29    NaN              NaN                                                NaN
# 30    NaN              NaN  We provide various statistics and data downloa...
# 31    NaN              NaN                                infected devices at
# 32    NaN              NaN  http://data.netlab.360.com/mirai-scanner for r...
# 33    NaN              NaN                                                NaN
# 34    NaN              NaN  For those who have been using API to access ou...
# 35    NaN              NaN                                 please re-download
# 36    NaN              NaN  the data from 2016-11-26 and later to obtain u...
# 37    NaN              NaN                                      7547 and 5555
# 38    NaN              NaN                                              data.
# 39    NaN              NaN                                                NaN
# 40    NaN              NaN  The New Variant Shares Some of the Infrastruct...
# 41    NaN              NaN                              Existing Mirai Botnet
# 42    NaN              NaN                                                NaN
# 43    NaN              NaN     The new mirai has two C2s (securityupdates.us,
# 44    NaN              NaN                    timeserver.host) and two report
# 45    NaN              NaN  servers (rep.securityupdates.us, ntp.timeserve...
# 46    NaN              NaN                                                NaN
# 47    NaN              NaN                                                  !
# 48  T1046  Network Service  The total number of bots on current port 7547 ...
# 49    NaN         Scanning                                   exceeded 30,000.
#        ID               Name  \
# 0     NaN                NaN
# 1     NaN                NaN
# 2     NaN                NaN
# 3     NaN                NaN
# 4     NaN                NaN
# 5     NaN                NaN
# 6     NaN                NaN
# 7     NaN                NaN
# 8     NaN                NaN
# 9     NaN                NaN
# 10    NaN                NaN
# 11    NaN                NaN
# 12    NaN                NaN
# 13    NaN                NaN
# 14    NaN                NaN
# 15    NaN                NaN
# 16    NaN                NaN
# 17    NaN                NaN
# 18    NaN                NaN
# 19    NaN                NaN
# 20    NaN                NaN
# 21    NaN                NaN
# 22    NaN                NaN
# 23    NaN                NaN
# 24    NaN                NaN
# 25    NaN                NaN
# 26    NaN                NaN
# 27    NaN                NaN
# 28    NaN                NaN
# 29    NaN                NaN
# 30    NaN                NaN
# 31    NaN                NaN
# 32    NaN                NaN
# 33    NaN                NaN
# 34    NaN                NaN
# 35    NaN                NaN
# 36    NaN                NaN
# 37    NaN                NaN
# 38    NaN                NaN
# 39    NaN                NaN
# 40    NaN                NaN
# 41  T1008  Fallback Channels
# 42    NaN                NaN
# 43    NaN                NaN
# 44    NaN                NaN
# 45    NaN                NaN
# 46    NaN                NaN
# 47    NaN                NaN
# 48    NaN                NaN
# 49    NaN                NaN
# 50    NaN                NaN
#
#                                   Identified Sentence
# 0                                                 NaN
# 1       Bot growth rate on port 7547, per 10 minutes:
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   The figure shows that, bot's growth rate quick...
# 6                                        and smoothly
# 7                         maintained at a high level.
# 8                                                 NaN
# 9   On the other hand, from the perspective of the...
# 10                               network, the scan on
# 11  port 7547 began to rise sharply in the evening...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  In terms of the geographical distribution of t...
# 16                                     bot, Brazil is
# 17  still far ahead of the others, which is consis...
# 18                                       geographical
# 19         distribution of the existing mirai botnet.
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  We provide various statistics and data downloa...
# 24                                infected devices at
# 25  http://data.netlab.360.com/mirai-scanner for r...
# 26                                                NaN
# 27  For those who have been using API to access ou...
# 28                                 please re-download
# 29  the data from 2016-11-26 and later to obtain u...
# 30                                      7547 and 5555
# 31                                              data.
# 32                                                NaN
# 33  The New Variant Shares Some of the Infrastruct...
# 34                              Existing Mirai Botnet
# 35                                                NaN
# 36     The new mirai has two C2s (securityupdates.us,
# 37                    timeserver.host) and two report
# 38  servers (rep.securityupdates.us, ntp.timeserve...
# 39                                                NaN
# 40                                                  !
# 41  The total number of bots on current port 7547 ...
# 42                                   exceeded 30,000.
# 43                                                NaN
# 44      Bot growth rate on port 7547, per 10 minutes:
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  The figure shows that, bot's growth rate quick...
# 49                                       and smoothly
# 50                        maintained at a high level.
#        ID                Name  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6     NaN                 NaN
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14    NaN                 NaN
# 15    NaN                 NaN
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18    NaN                 NaN
# 19    NaN                 NaN
# 20    NaN                 NaN
# 21    NaN                 NaN
# 22    NaN                 NaN
# 23    NaN                 NaN
# 24    NaN                 NaN
# 25    NaN                 NaN
# 26    NaN                 NaN
# 27    NaN                 NaN
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
# 32  T1043  Commonly Used Port
# 33    NaN                 NaN
# 34    NaN                 NaN
# 35    NaN                 NaN
# 36    NaN                 NaN
# 37    NaN                 NaN
# 38    NaN                 NaN
# 39    NaN                 NaN
# 40    NaN                 NaN
# 41    NaN                 NaN
# 42    NaN                 NaN
# 43    NaN                 NaN
# 44    NaN                 NaN
# 45    NaN                 NaN
# 46    NaN                 NaN
# 47    NaN                 NaN
# 48    NaN                 NaN
# 49    NaN                 NaN
# 50    NaN                 NaN
# 51    NaN                 NaN
#
#                                   Identified Sentence
# 0   On the other hand, from the perspective of the...
# 1                                network, the scan on
# 2   port 7547 began to rise sharply in the evening...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   In terms of the geographical distribution of t...
# 7                                      bot, Brazil is
# 8   still far ahead of the others, which is consis...
# 9                                        geographical
# 10         distribution of the existing mirai botnet.
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  We provide various statistics and data downloa...
# 15                                infected devices at
# 16  http://data.netlab.360.com/mirai-scanner for r...
# 17                                                NaN
# 18  For those who have been using API to access ou...
# 19                                 please re-download
# 20  the data from 2016-11-26 and later to obtain u...
# 21                                      7547 and 5555
# 22                                              data.
# 23                                                NaN
# 24  The New Variant Shares Some of the Infrastruct...
# 25                              Existing Mirai Botnet
# 26                                                NaN
# 27     The new mirai has two C2s (securityupdates.us,
# 28                    timeserver.host) and two report
# 29  servers (rep.securityupdates.us, ntp.timeserve...
# 30                                                NaN
# 31                                                  !
# 32  The total number of bots on current port 7547 ...
# 33                                   exceeded 30,000.
# 34                                                NaN
# 35      Bot growth rate on port 7547, per 10 minutes:
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  The figure shows that, bot's growth rate quick...
# 40                                       and smoothly
# 41                        maintained at a high level.
# 42                                                NaN
# 43  On the other hand, from the perspective of the...
# 44                               network, the scan on
# 45  port 7547 began to rise sharply in the evening...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  In terms of the geographical distribution of t...
# 50                                     bot, Brazil is
# 51  still far ahead of the others, which is consis...
#        ID               Name  \
# 0     NaN                NaN
# 1     NaN                NaN
# 2     NaN                NaN
# 3     NaN                NaN
# 4     NaN                NaN
# 5     NaN                NaN
# 6     NaN                NaN
# 7     NaN                NaN
# 8     NaN                NaN
# 9     NaN                NaN
# 10    NaN                NaN
# 11    NaN                NaN
# 12    NaN                NaN
# 13    NaN                NaN
# 14    NaN                NaN
# 15    NaN                NaN
# 16    NaN                NaN
# 17    NaN                NaN
# 18    NaN                NaN
# 19    NaN                NaN
# 20    NaN                NaN
# 21    NaN                NaN
# 22    NaN                NaN
# 23  T1008  Fallback Channels
# 24    NaN                NaN
# 25    NaN                NaN
# 26    NaN                NaN
# 27    NaN                NaN
# 28    NaN                NaN
# 29    NaN                NaN
# 30    NaN                NaN
# 31    NaN                NaN
# 32    NaN                NaN
# 33    NaN                NaN
# 34    NaN                NaN
# 35    NaN                NaN
# 36    NaN                NaN
# 37    NaN                NaN
# 38    NaN                NaN
# 39    NaN                NaN
# 40  T1065    Uncommonly Used
# 41    NaN               Port
# 42    NaN                NaN
# 43    NaN                NaN
# 44    NaN                NaN
# 45    NaN                NaN
# 46    NaN                NaN
# 47    NaN                NaN
# 48    NaN                NaN
#
#                                   Identified Sentence
# 0                                        geographical
# 1          distribution of the existing mirai botnet.
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   We provide various statistics and data downloa...
# 6                                 infected devices at
# 7   http://data.netlab.360.com/mirai-scanner for r...
# 8                                                 NaN
# 9   For those who have been using API to access ou...
# 10                                 please re-download
# 11  the data from 2016-11-26 and later to obtain u...
# 12                                      7547 and 5555
# 13                                              data.
# 14                                                NaN
# 15  The New Variant Shares Some of the Infrastruct...
# 16                              Existing Mirai Botnet
# 17                                                NaN
# 18     The new mirai has two C2s (securityupdates.us,
# 19                    timeserver.host) and two report
# 20  servers (rep.securityupdates.us, ntp.timeserve...
# 21                                                NaN
# 22                                                  !
# 23  [](/content/images/2016/11/07-two-c2-server-an...
# 24                                     server-in-one-
# 25          marai-sample---the-port-7547-varaint.jpg)
# 26                                                NaN
# 27  It is noteworthy the exact combination, both C...
# 28                                        servers had
# 29  previously been embedded in the “old” mirai sa...
# 30                                 saw a while ago on
# 31                                        2016-11-09.
# 32                                                NaN
# 33        Detail of the sample of 2016-11-09 variant:
# 34                                                NaN
# 35                               CRC32: 2BD6603A MD5:
# 36            EF713BDD7B06097447A25F4B35C738F6 SHA-1:
# 37           44D9C6A682E48DFA86BACDBD68F11A1F3CB78D07
# 38                                                NaN
# 39                                                  !
# 40  [](/content/images/2016/11/07-two-c2-server-an...
# 41                                     server-in-one-
# 42                                  marai-sample.jpg)
# 43                                                NaN
# 44                                        Bot Overlap
# 45                                                NaN
# 46  In other words, the operator of new variant on...
# 47                                       the previous
# 48  mirai operator are very likely the same group ...
#        ID                Name  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6     NaN                 NaN
# 7   T1046     Network Service
# 8     NaN            Scanning
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14    NaN                 NaN
# 15    NaN                 NaN
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18    NaN                 NaN
# 19    NaN                 NaN
# 20    NaN                 NaN
# 21    NaN                 NaN
# 22    NaN                 NaN
# 23    NaN                 NaN
# 24  T1008   Fallback Channels
# 25    NaN                 NaN
# 26    NaN                 NaN
# 27    NaN                 NaN
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
# 32    NaN                 NaN
# 33    NaN                 NaN
# 34    NaN                 NaN
# 35    NaN                 NaN
# 36    NaN                 NaN
# 37    NaN                 NaN
# 38    NaN                 NaN
# 39    NaN                 NaN
# 40    NaN                 NaN
# 41  T1043  Commonly Used Port
# 42    NaN                 NaN
# 43    NaN                 NaN
# 44    NaN                 NaN
# 45    NaN                 NaN
# 46    NaN                 NaN
# 47    NaN                 NaN
# 48    NaN                 NaN
#
#                                   Identified Sentence
# 0   The following diagram shows the overlap of all...
# 1                                     captured in our
# 2   honeypot that have scanned port 23/2323/5555/7...
# 3                                                 NaN
# 4                                    We can see that:
# 5                                                 NaN
# 6   96.4% of the Mirai Bots scan port 23 or port 2...
# 7   [](/content/images/2016/11/07-two-c2-server-an...
# 8                                      server-in-one-
# 9                                   marai-sample.jpg)
# 10                                                NaN
# 11                                        Bot Overlap
# 12                                                NaN
# 13  In other words, the operator of new variant on...
# 14                                       the previous
# 15  mirai operator are very likely the same group ...
# 16                                                NaN
# 17  The following diagram shows the overlap of all...
# 18                                    captured in our
# 19  honeypot that have scanned port 23/2323/5555/7...
# 20                                                NaN
# 21                                   We can see that:
# 22                                                NaN
# 23  96.4% of the Mirai Bots scan port 23 or port 2...
# 24  [](/content/images/2016/11/07-two-c2-server-an...
# 25                                     server-in-one-
# 26                                  marai-sample.jpg)
# 27                                                NaN
# 28                                        Bot Overlap
# 29                                                NaN
# 30  In other words, the operator of new variant on...
# 31                                       the previous
# 32  mirai operator are very likely the same group ...
# 33                                                NaN
# 34  The following diagram shows the overlap of all...
# 35                                    captured in our
# 36  honeypot that have scanned port 23/2323/5555/7...
# 37                                                NaN
# 38                                   We can see that:
# 39                                                NaN
# 40  96.4% of the Mirai Bots scan port 23 or port 2...
# 41  [](/content/images/2016/11/07-two-c2-server-an...
# 42                                     server-in-one-
# 43                                  marai-sample.jpg)
# 44                                                NaN
# 45                                        Bot Overlap
# 46                                                NaN
# 47  In other words, the operator of new variant on...
# 48                                       the previous
#        ID                Name  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6     NaN                 NaN
# 7     NaN                 NaN
# 8     NaN                 NaN
# 9   T1065     Uncommonly Used
# 10    NaN                Port
# 11    NaN                 NaN
# 12  T1046     Network Service
# 13    NaN            Scanning
# 14    NaN                 NaN
# 15  T1043  Commonly Used Port
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18  T1046     Network Service
# 19    NaN            Scanning
# 20  T1046     Network Service
# 21    NaN            Scanning
# 22    NaN                 NaN
# 23    NaN                 NaN
# 24    NaN                 NaN
# 25    NaN                 NaN
# 26    NaN                 NaN
# 27    NaN                 NaN
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
# 32    NaN                 NaN
#
#                                   Identified Sentence
# 0   mirai operator are very likely the same group ...
# 1                                                 NaN
# 2   The following diagram shows the overlap of all...
# 3                                     captured in our
# 4   honeypot that have scanned port 23/2323/5555/7...
# 5                                                 NaN
# 6                                    We can see that:
# 7                                                 NaN
# 8   96.4% of the Mirai Bots scan port 23 or port 2...
# 9   Among them, 79% only scan port 23 and 6.4% onl...
# 10                                 11% scan both port
# 11                                       23 and 2323.
# 12  Among them, 79% only scan port 23 and 6.4% onl...
# 13                                 11% scan both port
# 14                                       23 and 2323.
# 15  Among them, 79% only scan port 23 and 6.4% onl...
# 16                                 11% scan both port
# 17                                       23 and 2323.
# 18  About 3.1% of the Mirai bots only scan port 7547.
# 19                                                NaN
# 20  No more than 0.1% of the bots show other cross...
# 21                                behaviors among the
# 22             four-ports, which is still quite rare.
# 23                                                NaN
# 24                          Infected Device Breakdown
# 25                                                NaN
# 26  All together we have logged 46,653 IPs that we...
# 27                                      this new 7547
# 28  variants, and we tried to ID these known infec...
# 29                                       out requests
# 30  that emulate tr064|tr069 protocol so we would ...
# 31                                    accurate device
# 32                                              info.

# %%
df[6]
# Out:
#        ID                Name  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6   T1046     Network Service
# 7     NaN            Scanning
# 8     NaN                 NaN
# 9     NaN                 NaN
# 10    NaN                 NaN
# 11    NaN                 NaN
# 12    NaN                 NaN
# 13    NaN                 NaN
# 14    NaN                 NaN
# 15    NaN                 NaN
# 16    NaN                 NaN
# 17    NaN                 NaN
# 18    NaN                 NaN
# 19    NaN                 NaN
# 20    NaN                 NaN
# 21    NaN                 NaN
# 22    NaN                 NaN
# 23  T1008   Fallback Channels
# 24    NaN                 NaN
# 25    NaN                 NaN
# 26    NaN                 NaN
# 27    NaN                 NaN
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
# 32    NaN                 NaN
# 33    NaN                 NaN
# 34    NaN                 NaN
# 35    NaN                 NaN
# 36    NaN                 NaN
# 37    NaN                 NaN
# 38    NaN                 NaN
# 39    NaN                 NaN
# 40  T1043  Commonly Used Port
# 41    NaN                 NaN
# 42    NaN                 NaN
# 43    NaN                 NaN
# 44    NaN                 NaN
# 45    NaN                 NaN
# 46    NaN                 NaN
# 47    NaN                 NaN
#
#                                   Identified Sentence
# 0                                     captured in our
# 1   honeypot that have scanned port 23/2323/5555/7...
# 2                                                 NaN
# 3                                    We can see that:
# 4                                                 NaN
# 5   96.4% of the Mirai Bots scan port 23 or port 2...
# 6   [](/content/images/2016/11/07-two-c2-server-an...
# 7                                      server-in-one-
# 8                                   marai-sample.jpg)
# 9                                                 NaN
# 10                                        Bot Overlap
# 11                                                NaN
# 12  In other words, the operator of new variant on...
# 13                                       the previous
# 14  mirai operator are very likely the same group ...
# 15                                                NaN
# 16  The following diagram shows the overlap of all...
# 17                                    captured in our
# 18  honeypot that have scanned port 23/2323/5555/7...
# 19                                                NaN
# 20                                   We can see that:
# 21                                                NaN
# 22  96.4% of the Mirai Bots scan port 23 or port 2...
# 23  [](/content/images/2016/11/07-two-c2-server-an...
# 24                                     server-in-one-
# 25                                  marai-sample.jpg)
# 26                                                NaN
# 27                                        Bot Overlap
# 28                                                NaN
# 29  In other words, the operator of new variant on...
# 30                                       the previous
# 31  mirai operator are very likely the same group ...
# 32                                                NaN
# 33  The following diagram shows the overlap of all...
# 34                                    captured in our
# 35  honeypot that have scanned port 23/2323/5555/7...
# 36                                                NaN
# 37                                   We can see that:
# 38                                                NaN
# 39  96.4% of the Mirai Bots scan port 23 or port 2...
# 40  [](/content/images/2016/11/07-two-c2-server-an...
# 41                                     server-in-one-
# 42                                  marai-sample.jpg)
# 43                                                NaN
# 44                                        Bot Overlap
# 45                                                NaN
# 46  In other words, the operator of new variant on...
# 47                                       the previous

# %%
df[5]
# Out:
#    Unnamed: 0         Unnamed: 1  \
# 0         NaN                NaN
# 1         NaN                NaN
# 2         NaN                NaN
# 3         NaN                NaN
# 4         NaN                NaN
# 5         NaN                NaN
# 6         NaN                NaN
# 7         NaN                NaN
# 8         NaN                NaN
# 9         NaN                NaN
# 10        NaN                NaN
# 11        NaN                NaN
# 12        NaN                NaN
# 13        NaN                NaN
# 14        NaN                NaN
# 15        NaN                NaN
# 16        NaN                NaN
# 17        NaN                NaN
# 18        NaN                NaN
# 19        NaN                NaN
# 20        NaN                NaN
# 21        NaN                NaN
# 22      T1008  Fallback Channels
# 23        NaN                NaN
# 24        NaN                NaN
# 25        NaN                NaN
# 26        NaN                NaN
# 27        NaN                NaN
# 28        NaN                NaN
# 29        NaN                NaN
# 30        NaN                NaN
# 31        NaN                NaN
# 32        NaN                NaN
# 33        NaN                NaN
# 34        NaN                NaN
# 35        NaN                NaN
# 36        NaN                NaN
# 37        NaN                NaN
# 38        NaN                NaN
# 39      T1065    Uncommonly Used
# 40        NaN               Port
# 41        NaN                NaN
# 42        NaN                NaN
# 43        NaN                NaN
# 44        NaN                NaN
# 45        NaN                NaN
# 46        NaN                NaN
# 47        NaN                NaN
#
#                                          geographical
# 0          distribution of the existing mirai botnet.
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   We provide various statistics and data downloa...
# 5                                 infected devices at
# 6   http://data.netlab.360.com/mirai-scanner for r...
# 7                                                 NaN
# 8   For those who have been using API to access ou...
# 9                                  please re-download
# 10  the data from 2016-11-26 and later to obtain u...
# 11                                      7547 and 5555
# 12                                              data.
# 13                                                NaN
# 14  The New Variant Shares Some of the Infrastruct...
# 15                              Existing Mirai Botnet
# 16                                                NaN
# 17     The new mirai has two C2s (securityupdates.us,
# 18                    timeserver.host) and two report
# 19  servers (rep.securityupdates.us, ntp.timeserve...
# 20                                                NaN
# 21                                                  !
# 22  [](/content/images/2016/11/07-two-c2-server-an...
# 23                                     server-in-one-
# 24          marai-sample---the-port-7547-varaint.jpg)
# 25                                                NaN
# 26  It is noteworthy the exact combination, both C...
# 27                                        servers had
# 28  previously been embedded in the “old” mirai sa...
# 29                                 saw a while ago on
# 30                                        2016-11-09.
# 31                                                NaN
# 32        Detail of the sample of 2016-11-09 variant:
# 33                                                NaN
# 34                               CRC32: 2BD6603A MD5:
# 35            EF713BDD7B06097447A25F4B35C738F6 SHA-1:
# 36           44D9C6A682E48DFA86BACDBD68F11A1F3CB78D07
# 37                                                NaN
# 38                                                  !
# 39  [](/content/images/2016/11/07-two-c2-server-an...
# 40                                     server-in-one-
# 41                                  marai-sample.jpg)
# 42                                                NaN
# 43                                        Bot Overlap
# 44                                                NaN
# 45  In other words, the operator of new variant on...
# 46                                       the previous
# 47  mirai operator are very likely the same group ...

# %%
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
if (df[1].columns != ['ID', 'Name', 'Identified Sentence']).any():
    df[1].columns = ['ID', 'Name', 'Identified Sentence']
df[1]
# Out:
#        ID                  Name  \
# 0     NaN              Scanning
# 1     NaN                   NaN
# 2     NaN                   NaN
# 3     NaN                   NaN
# 4     NaN                   NaN
# 5   T1043    Commonly Used Port
# 6     NaN                   NaN
# 7     NaN                   NaN
# 8     NaN                   NaN
# 9     NaN                   NaN
# 10    NaN                   NaN
# 11  T1048     Exfiltration Over
# 12    NaN  Alternative Protocol
# 13    NaN                   NaN
# 14    NaN                   NaN
# 15    NaN                   NaN
# 16    NaN                   NaN
# 17    NaN                   NaN
# 18    NaN                   NaN
# 19    NaN                   NaN
# 20    NaN                   NaN
# 21    NaN                   NaN
# 22    NaN                   NaN
# 23    NaN                   NaN
# 24    NaN                   NaN
# 25    NaN                   NaN
# 26    NaN                   NaN
# 27    NaN                   NaN
# 28    NaN                   NaN
# 29    NaN                   NaN
# 30    NaN                   NaN
# 31    NaN                   NaN
# 32    NaN                   NaN
# 33    NaN                   NaN
# 34    NaN                   NaN
# 35    NaN                   NaN
# 36    NaN                   NaN
# 37    NaN                   NaN
# 38    NaN                   NaN
# 39    NaN                   NaN
# 40    NaN                   NaN
# 41    NaN                   NaN
# 42    NaN                   NaN
# 43    NaN                   NaN
# 44    NaN                   NaN
# 45    NaN                   NaN
# 46    NaN                   NaN
# 47    NaN                   NaN
#
#                                   Identified Sentence
# 0                                           port.jpg)
# 1                                                 NaN
# 2   Currently, the growth rate of the bot on port ...
# 3                                 exceeded the number
# 4                            of bots on port 23/2323.
# 5   [](/content/images/2016/11/03-bot-current-grow...
# 6                                           port.jpg)
# 7                                                 NaN
# 8   Currently, the growth rate of the bot on port ...
# 9                                 exceeded the number
# 10                           of bots on port 23/2323.
# 11  The total number of bots on current port 7547 ...
# 12                                   exceeded 30,000.
# 13                                                NaN
# 14      Bot growth rate on port 7547, per 10 minutes:
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  The figure shows that, bot's growth rate quick...
# 19                                       and smoothly
# 20                        maintained at a high level.
# 21                                                NaN
# 22  On the other hand, from the perspective of the...
# 23                               network, the scan on
# 24  port 7547 began to rise sharply in the evening...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  In terms of the geographical distribution of t...
# 29                                     bot, Brazil is
# 30  still far ahead of the others, which is consis...
# 31                                       geographical
# 32         distribution of the existing mirai botnet.
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  We provide various statistics and data downloa...
# 37                                infected devices at
# 38  http://data.netlab.360.com/mirai-scanner for r...
# 39                                                NaN
# 40  For those who have been using API to access ou...
# 41                                 please re-download
# 42  the data from 2016-11-26 and later to obtain u...
# 43                                      7547 and 5555
# 44                                              data.
# 45                                                NaN
# 46  The New Variant Shares Some of the Infrastruct...
# 47                              Existing Mirai Botnet

# %%
valid_tids, indexes = extract_tids(df[0])

# %%
valid_names = extract_names(df[0])
valid_names
# Out:
# ['Network Service Scanning',
#  'Uncommonly Used Port',
#  'Port',
#  'Commonly Used Port',
#  'Uncommonly Used Port',
#  'Port']

# %%
df[7].columns = ['a', 'b', 'c']

# %%
df[7]
# Out:
#         a                   b  \
# 0     NaN                 NaN
# 1     NaN                 NaN
# 2     NaN                 NaN
# 3     NaN                 NaN
# 4     NaN                 NaN
# 5     NaN                 NaN
# 6     NaN                 NaN
# 7     NaN                 NaN
# 8   T1065     Uncommonly Used
# 9     NaN                Port
# 10    NaN                 NaN
# 11  T1046     Network Service
# 12    NaN            Scanning
# 13    NaN                 NaN
# 14  T1043  Commonly Used Port
# 15    NaN                 NaN
# 16    NaN                 NaN
# 17  T1046     Network Service
# 18    NaN            Scanning
# 19  T1046     Network Service
# 20    NaN            Scanning
# 21    NaN                 NaN
# 22    NaN                 NaN
# 23    NaN                 NaN
# 24    NaN                 NaN
# 25    NaN                 NaN
# 26    NaN                 NaN
# 27    NaN                 NaN
# 28    NaN                 NaN
# 29    NaN                 NaN
# 30    NaN                 NaN
# 31    NaN                 NaN
#
#                                                     c
# 0                                                 NaN
# 1   The following diagram shows the overlap of all...
# 2                                     captured in our
# 3   honeypot that have scanned port 23/2323/5555/7...
# 4                                                 NaN
# 5                                    We can see that:
# 6                                                 NaN
# 7   96.4% of the Mirai Bots scan port 23 or port 2...
# 8   Among them, 79% only scan port 23 and 6.4% onl...
# 9                                  11% scan both port
# 10                                       23 and 2323.
# 11  Among them, 79% only scan port 23 and 6.4% onl...
# 12                                 11% scan both port
# 13                                       23 and 2323.
# 14  Among them, 79% only scan port 23 and 6.4% onl...
# 15                                 11% scan both port
# 16                                       23 and 2323.
# 17  About 3.1% of the Mirai bots only scan port 7547.
# 18                                                NaN
# 19  No more than 0.1% of the bots show other cross...
# 20                                behaviors among the
# 21             four-ports, which is still quite rare.
# 22                                                NaN
# 23                          Infected Device Breakdown
# 24                                                NaN
# 25  All together we have logged 46,653 IPs that we...
# 26                                      this new 7547
# 27  variants, and we tried to ID these known infec...
# 28                                       out requests
# 29  that emulate tr064|tr069 protocol so we would ...
# 30                                    accurate device
# 31                                              info.
